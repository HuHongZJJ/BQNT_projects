# %%
import importlib
import application
import bql 
bq=bql.Service()
importlib.reload(application)


app =application.Application(bq, ud_main_group_values= ['Hybrid / Balanced Funds',
 'National Muni Bond Funds',
 'Non U.S. Equity Funds',
 'Single State Muni Bond Funds',
 'Specialty Equity Funds',
 'Taxable Bond Funds',
 'U.S. Equity Funds'])
app.app
